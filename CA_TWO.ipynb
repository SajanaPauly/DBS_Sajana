# %% [markdown]
# <a href="https://colab.research.google.com/github/SajanaPauly/DBS_Sajana/blob/main/CA_TWO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
from csv import writer

# %%
Product_name = []
Prices = []
Description = []
Reviews = []

for i in range(2,12):

 url= "https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off" + str(i)
 r = requests.get(url)
   #print(r)

 soup = BeautifulSoup(r.text,"lxml")
 box = soup.find("div", class_="_1YokD2 _3Mn1Gg")


 names = box.find_all("div",class_="_4rR01T")
 for i in names:
  name=i.text
  Product_name.append(name)
 print(Product_name)

 prices = box.find_all("div",class_="_30jeq3 _1_WHN1")
 for i in prices:
  name=i.text
  Prices.append(name)
 print(Prices)

 desc = box.find_all("ul",class_="_1xgFaf")
 for i in desc:
  name=i.text
  Description.append(name)
 print(Description)

 reviews = box.find_all("div",class_="_3LWZlK")
 for i in reviews:
  name=i.text
  Reviews.append(name)
 print(Reviews)
# Out:
# ['APPLE iPhone 11 (Black, 128 GB)', 'APPLE iPhone 11 (White, 128 GB)', 'APPLE iPhone 12 Mini (Black, 128 GB)', 'APPLE iPhone 11 (Yellow, 128 GB)', 'APPLE iPhone 12 Mini (White, 128 GB)', 'SAMSUNG Galaxy S21 FE 5G (Olive, 128 GB)', 'OPPO Reno8 Pro 5G - House of The Dragon (House of The Dragon, 256 GB)', 'APPLE iPhone 11 (Purple, 128 GB)', 'APPLE iPhone 11 (Green, 128 GB)', 'OPPO Reno8 Pro 5G (Glazed Black, 256 GB)', 'IQOO 9T 5G (ALPHA, 128 GB)', 'SAMSUNG Galaxy S20 FE (Cloud Navy, 128 GB)', 'realme GT 2 Pro (Paper Green, 128 GB)', 'realme GT 2 Pro (Paper White, 128 GB)', 'realme GT 2 Pro (Steel Black, 128 GB)', 'realme X50 Pro 5G (Rust Red, 256 GB)', 'SAMSUNG Galaxy A73 5G (Awesome Gray, 128 GB)', 'OPPO Reno8 Pro 5G (Glazed Green, 256 GB)', 'ASUS ROG 5s (Black, 128 GB)', 'SAMSUNG Galaxy S7 (Gold Platinum, 32 GB)', 'OPPO R17 Pro (Emerald Green, 128 GB)', 'APPLE iPhone 8 Plus (Gold, 64 GB)', 'APPLE iPhone 8 Plus (Space Grey, 64 GB)', 'APPLE iPhone 8 Plus (Silver, 64 GB)']
# ...

# %%
a = {"Product Name":Product_name,"Prices":Prices,"Description":Description,"Reviews":Reviews}
df = pd.DataFrame.from_dict(a, orient='index')
df = df.transpose()
